# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

df = pd.read_csv("/kaggle/input/heart-disease-dataset/heart.csv")

# %%
df.head(20)

# %%
import pandas_profiling as pp
pp.ProfileReport(df)

# %%
cor = df.corr()
sns.heatmap(cor,annot = True)

# %%
df.shape

# %%
df.describe()

# %%
df.isna().sum()

# %%
df.loc[df.duplicated()]

# %%
df = df.drop_duplicates()

# %%
df.shape

# %%
num_cols = df.columns

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(df[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.show()

# %%
max_trestbps  = df['trestbps'].quantile(0.97)
df = df[(df['trestbps']<max_trestbps )]

# %%
max_chol  = df['chol'].quantile(0.97)
df = df[(df['chol']<max_chol )]

# %%
max_thalach  = df['thalach'].quantile(0.02)
df = df[(df['thalach']>max_thalach )]

# %%
max_oldpeak  = df['oldpeak'].quantile(0.97)
df = df[(df['oldpeak']<max_oldpeak )]

# %%
df.shape

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2, random_state = 0)
print(x_train)

# %%
print(x_test)

# %%
print(y_train)

# %%
print(y_test)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier1 = LogisticRegression(random_state = 0)
classifier1.fit(x_train,y_train)

y_pred1=classifier1.predict(x_test)
#print(np.concatenate((y_pred1.reshape(-1,1),y_test.reshape(-1,1)),1))

from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
print(confusion_matrix(y_test,y_pred1))
print("accuracy:",accuracy_score(y_test, y_pred1)*100)
print("Recall:",recall_score(y_test, y_pred1))

# %%
from sklearn.neighbors import KNeighborsClassifier 
classifier2 = KNeighborsClassifier (n_neighbors = 10, metric = 'minkowski', p=2)
classifier2.fit(x_train,y_train)

y_pred2=classifier2.predict(x_test)
#print(np.concatenate((y_pred2.reshape(-1,1),y_test.reshape(-1,1)),1))

print(confusion_matrix(y_test,y_pred2))
print("accuracy:",accuracy_score(y_test, y_pred2)*100)
print("Recall:",recall_score(y_test, y_pred2))

# %%
from sklearn.svm import SVC
classifier3 = SVC(kernel = 'linear', random_state = 0)
classifier3.fit(x_train, y_train)

y_pred3=classifier3.predict(x_test)
#print(np.concatenate((y_pred3.reshape(-1,1),y_test.reshape(-1,1)),1))

from sklearn.metrics import confusion_matrix, accuracy_score
print(confusion_matrix(y_test,y_pred3))
print("accuracy:",accuracy_score(y_test, y_pred3)*100)
print("Recall:",recall_score(y_test, y_pred3))

# %%
from sklearn.tree import DecisionTreeClassifier
classifier4 = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier4.fit(x_train, y_train)

y_pred4=classifier4.predict(x_test)
#print(np.concatenate((y_pred4.reshape(-1,1),y_test.reshape(-1,1)),1))

print(confusion_matrix(y_test,y_pred4))
print("accuracy:",accuracy_score(y_test, y_pred4)*100)
print("Recall:",recall_score(y_test, y_pred4))

# %%
from sklearn.naive_bayes import GaussianNB
classifier5 = GaussianNB()
classifier5.fit(x_train, y_train)

y_pred5=classifier5.predict(x_test)
#print(np.concatenate((y_pred5.reshape(-1,1),y_test.reshape(-1,1)),1))

print(confusion_matrix(y_test,y_pred5))
print("accuracy:",accuracy_score(y_test, y_pred5)*100)
print("Recall:",recall_score(y_test, y_pred5))

# %%
from sklearn.ensemble import RandomForestClassifier
classifier6 = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier6.fit(x_train, y_train)

y_pred6=classifier6.predict(x_test)
#print(np.concatenate((y_pred6.reshape(-1,1),y_test.reshape(-1,1)),1))

print(confusion_matrix(y_test,y_pred6))
print("accuracy:",accuracy_score(y_test, y_pred6)*100)
print("Recall:",recall_score(y_test, y_pred6))

# %%
from sklearn.svm import SVC
classifier7 = SVC(kernel = 'rbf', random_state = 0)
classifier7.fit(x_train, y_train)

y_pred7=classifier7.predict(x_test)
#print(np.concatenate((y_pred7.reshape(-1,1),y_test.reshape(-1,1)),1))

print(confusion_matrix(y_test,y_pred7))
print("accuracy:",accuracy_score(y_test, y_pred7)*100)
print("Recall:",recall_score(y_test, y_pred7))

# %%
mod=pd.DataFrame({"MODEL":["Logistic Regression","KNN classifier","naive bayes classifier","SVM classifier","SVM Kernel","Decision Tree","Random Forest classifier"],"Accuracy":[accuracy_score(y_test, y_pred1)*100,accuracy_score(y_test, y_pred2)*100,accuracy_score(y_test, y_pred5)*100,accuracy_score(y_test, y_pred3)*100,accuracy_score(y_test, y_pred7)*100,accuracy_score(y_test, y_pred4)*100,accuracy_score(y_test, y_pred6)*100]})
mod
